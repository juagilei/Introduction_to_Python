# %% [markdown]
# # Ejercicio: Control de ITV para vehículos
#
# En este ejercicio, se te proporciona un diccionario que contiene información de varios vehículos. Cada vehículo se identifica por su matrícula y tiene asociados los siguientes datos: el nombre del propietario, su número de DNI, su dirección de correo electrónico y el año del coche.
#
# Tu tarea es crear un programa en Python que realice las siguientes acciones:
#
# - Definir una función llamada es_multiplo_de_tres(año) que reciba como argumento un número entero representando el año del coche y devuelva True si el año es múltiplo de 3, o False en caso contrario.
#
# - Definir una función llamada vehiculos_itv(vehiculos) que reciba el diccionario de vehículos como argumento y determine cuáles de ellos deben pasar la Inspección Técnica de Vehículos (ITV) este año. Si el año del coche es múltiplo de 3, el vehículo debe pasar la ITV. Esta función debe devolver una lista de mensajes con la siguiente estructura:
#
# ["Mensaje 1", "Mensaje 2", ...]
#
# Donde cada mensaje debe indicar al propietario del vehículo que debe pasar la ITV, y debe incluir la matrícula, el nombre del propietario y su dirección de correo electrónico.
#
# - Utilizando la función vehiculos_itv, muestra por pantalla los mensajes que deben recibir los propietarios de los vehículos que deben pasar la ITV este año.
#
# - Finalmente, muestra un listado general de las matrículas de los vehículos que deben pasar la ITV este año.

# %% [markdown]
# ### Datos a usar:
#
# (para que los copieis y useis en vuestro codigo)

# %%
vehiculos = {
    "1234ABC": {
        "propietario": "Juan Pérez",
        "dni": "12345678A",
        "correo_electronico": "juan.perez@example.com",
        "año_coche": 2015
    },
    "5678XYZ": {
        "propietario": "María Gómez",
        "dni": "98765432Z",
        "correo_electronico": "maria.gomez@example.com",
        "año_coche": 2018
    },
    "AB123CD": {
        "propietario": "Luis Rodríguez",
        "dni": "87654321B",
        "correo_electronico": "luis.rodriguez@example.com",
        "año_coche": 2007
    },
    "ZX789YX": {
        "propietario": "Ana Martínez",
        "dni": "65432198X",
        "correo_electronico": "ana.martinez@example.com",
        "año_coche": 2012
    },
    "BC456FG": {
        "propietario": "Carlos Gutiérrez",
        "dni": "23456789C",
        "correo_electronico": "carlos.gutierrez@example.com",
        "año_coche": 2019
    },
    "GH908KL": {
        "propietario": "Laura Sánchez",
        "dni": "87654321L",
        "correo_electronico": "laura.sanchez@example.com",
        "año_coche": 2010
    },
    "JK567YH": {
        "propietario": "Pedro Ruiz",
        "dni": "76543210R",
        "correo_electronico": "pedro.ruiz@example.com",
        "año_coche": 2009
    },
    "DE876NO": {
        "propietario": "Isabel Torres",
        "dni": "54321098T",
        "correo_electronico": "isabel.torres@example.com",
        "año_coche": 2004
    },
    "TR765VB": {
        "propietario": "Antonio González",
        "dni": "32109876G",
        "correo_electronico": "antonio.gonzalez@example.com",
        "año_coche": 2002
    },
    "PO567RF": {
        "propietario": "Elena Vargas",
        "dni": "89012345V",
        "correo_electronico": "elena.vargas@example.com",
        "año_coche": 2017
    },
    "IJ978CB": {
        "propietario": "Miguel Castro",
        "dni": "10987654C",
        "correo_electronico": "miguel.castro@example.com",
        "año_coche": 2016
    },
    "VN876FR": {
        "propietario": "Carmen López",
        "dni": "67890123L",
        "correo_electronico": "carmen.lopez@example.com",
        "año_coche": 2008
    },
    "TF109KL": {
        "propietario": "David Ramírez",
        "dni": "78901234R",
        "correo_electronico": "david.ramirez@example.com",
        "año_coche": 2006
    },
    "WE901TQ": {
        "propietario": "Sara Núñez",
        "dni": "54321098N",
        "correo_electronico": "sara.nunez@example.com",
        "año_coche": 2005
    },
    "RO763ZQ": {
        "propietario": "Manuel Fernández",
        "dni": "21098765F",
        "correo_electronico": "manuel.fernandez@example.com",
        "año_coche": 2014
    },
    "OP458TY": {
        "propietario": "Cristina Ruiz",
        "dni": "32109876R",
        "correo_electronico": "cristina.ruiz@example.com",
        "año_coche": 2013
    },
    "XQ871LC": {
        "propietario": "Javier Torres",
        "dni": "76543210T",
        "correo_electronico": "javier.torres@example.com",
        "año_coche": 2011
    },
    "ZX678RT": {
        "propietario": "Sonia García",
        "dni": "56789012G",
        "correo_electronico": "sonia.garcia@example.com",
        "año_coche": 2003
    },
    "GH956PO": {
        "propietario": "Marta Martínez",
        "dni": "67890123M",
        "correo_electronico": "marta.martinez@example.com",
        "año_coche": 2017
    }
}

# %% [markdown]
# ### Acordaos de la importancia de dividir el codigo en bloques

# %% [markdown]
# #### Bloque 1: Definir una función para comprobar si un año es múltiplo de 3.
# - Pista: Puedes usar el operador módulo % para calcular el residuo de la división por 3. Si el residuo es 0, entonces el año es múltiplo de 3.
#
# #### Bloque 2: Definir una función que reciba el diccionario de vehículos y compruebe cuáles de ellos deben pasar la ITV este año.
# - Pista: Utiliza un bucle para recorrer el diccionario de vehículos. Luego, verifica si el año del coche es múltiplo de 3 utilizando la función del Bloque 1. Si es así, guarda el mensaje en una lista junto con los datos del vehículo (matrícula, propietario y correo electrónico).
#
# #### Bloque 3: Enviar los mensajes a los propietarios de los vehículos que deben pasar la ITV.
# - Pista: Utiliza un bucle para recorrer la lista de mensajes generada en el Bloque 2. Imprime un mensaje para cada vehículo indicando que debe pasar la ITV y muestra sus datos (matrícula, propietario y correo electrónico).
#
# #### Bloque 4: Mostrar el listado general de vehículos que deben pasar la ITV este año.
# - Pista: Utiliza el diccionario original de vehículos y el resultado del Bloque 2 para imprimir un listado con las matrículas de los vehículos que deben pasar la ITV.

# %% [markdown]
# #### En este caso solo habrá estas pistas

# %%
# Definir una función para comprobar si un año es múltiplo de 3.
def es_multiplo_de_tres(año):

# Definir una función que determine cuáles vehículos deben pasar la ITV este año.
def vehiculos_itv(vehiculos):

# Mostrar los mensajes que deben recibir los propietarios de los vehículos que deben pasar la ITV.
def mostrar_mensajes(mensajes):

# Mostrar un listado general de las matrículas de los vehículos que deben pasar la ITV.
def mostrar_matriculas(vehiculos):

# Diccionario de vehículos
vehiculos = {

# Llamada a las funciones para obtener los resultados
mensajes_itv = vehiculos_itv(vehiculos)
mostrar_mensajes(mensajes_itv)
mostrar_matriculas(vehiculos)
